# %% [markdown]
# # Marketing data analytical metrics
#
# ## Initial Metrics
# 1. Budget
# 2. Goal: click, sales, call
#
# ## Business Performance Metrics
# 1. **CPA - Cost Per Acquisition:** The cost to acquire a lead or customer. Indicates the efficiency of your campaigns in generating valuable leads. Test ad channels, refine targeting, and focus on high-value conversions.
# 1. **ROI - Return on Investment:** The revenue generated from leads compared to the cost of acquiring them. Reflects the overall profitability of your lead generation campaigns.
# 1. **LTV - Lifetime Customer Value:** Average of total amount of spent of customers
# 1. **LVR - Lead Velocity Rate:** The growth rate of qualified leads month-over-month. Indicates whether your lead generation strategies are scaling effectively.
#
# ## Lead Metrics
# 1. **CLV - Customer Lifetime Value:** The estimated total value a lead brings over time. Helps determine if lead acquisition costs are justified based on long-term revenue.
# 1. **Lead-to-Conversion Rate:** The percentage of leads that convert into paying customers. Directly reflects lead quality and overall campaign success. Focus on targeting high-intent audiences and refining your lead nurturing process.
# 1. **CPQL - Cost Per Qualified Lead:** The cost of acquiring a lead that meets qualification criteria. Focuses on the efficiency of generating valuable leads rather than overall volume. Reduce spend on low-performing channels or audiences.
# 1. **Lead scoring:** A scoring system that evaluates leads based on behavior, demographics, and firmographics. Prioritizes leads most likely to convert. Continuously refine the scoring model based on conversion data.
# 1. **Lead Engagement Metrics:** The degree of interaction with your brand, e.g., email open rates. Indicates interest and readiness to engage further. Create engaging follow-ups and nurture sequences.
#
# ## Website Metrics
# 1. Sessions: Total amount of time a new session has started on your website
# 1. Unique Visitors: How many unique visitors have visited your website
# 1. **Bounce Rate:** The percentage of visitors who leave your landing page without interacting. Indicate a disconnect between your ad and landing page content. Improve landing page relevance, design, and loading speed.
# 1. **CVR - Conversion Rate:** The percentage of ad clicks that lead to a desired action. Directly measures how well your ad drives conversions. Ensure ad targeting matches the audience intent, align landing pages with ad content, and optimize user experience.
#
# ## Ad/Social Media Metrics
# 1. Impression: Total amount of people who have seen your post/ads, even if they're the same person
# 1. CPM - Cost Per Mille: How much to get 1000 Impression
# 1. Reach: How many unique individual have seen that post/ads
# 1. Clicks/Calls/Visits: Measurement of how many people have clicked/called/visited you
# 1. Frequency: How often a person has seen your ads, e.g. 15 Frequency = 1 person has seen your ads 15 times
# 1. **CTR - Click Through Rate:** The percentage of people who clicked your ad after seeing it. Indicates that your ad creative and messaging resonate with the audience. Optimize ad copy, visuals, and call-to-action (CTA).
# 1. **CPC - Cost Per Click:** The cost incurred for each click on your ad. Helps evaluate ad efficiency and optimize spend for better ROI. Adjust bidding strategies, focus on high-performing keywords, or refine audience targeting.

# %% [markdown]
# #ETL & EDA Flow
#
# ## 1. Analyse requirements
#  1. Collect requirements
#  2. Collect data features (if seperated)
#  3. Choose EDA available based on the features
#
# ## 2. ETL Pipeline
#  1. Data collection
#  2. Data cleaning
#   + Remove duplicates: Identify and eliminate any duplicate records to avoid bias and ensure data integrity.
#   + Remove irrelevant data: Discard any columns or features that are not relevant to the analysis, such as unnecessary metadata or unrelated information.
#   + Fix missing values: Identify and handle missing data using appropriate techniques, such as imputation or removal.
#   + Standardize Fields: Correct any data entry errors, inconsistencies, or outliers that could affect the accuracy of the analysis.
#   + Evaluate data quality: Ensuring that the dataset quality is enough to be analysed to get the requirements
#
# ## 3. Exploratory Data Analysis (EDA)
#  1. Correlation analysis: examine relationships between different variables, like price and volume.
#  2. Descriptive statistics: calculate basic statistics to summarize the data, like mean, median, standard deviation, etc.
#  3. Identify potential dataset issues: such as outliers or inconsistencies that may need further investigation.
#  4. Data visualization: create plots and charts to visualize patterns, trends, and relationships in the data.
#
# ## 4. Conclusion
#  1. Key insights: identify the most significant insights and patterns found in the data.
#  2. Future directions: outline potential future steps for further research or model development.

# %% [markdown]
# #Dashboard Flow
#
# ## 1. Analyse requirements
#  1. Collect requirements
#  2. Choose the right chart
#  3. Draw Mockups
#  4. Choose color/appearance
#
# ## 2. Build Data Source
#  1. Connect data
#  2. Create data model
#  3. Rename fields & tables
#  4. Check data types
#  5. Understand data
#
# ## 3. Build Charts
#  1. Create calculated fields & test
#  2. Build chart
#  3. Format - Remove lines & Grids
#  4. Format - Clean up axis & Headers
#  5. Format - Coloring
#  6. Tooltips
#
# ## 4. Build Dashboard
#  1. Draw mockup for container
#  2. Create container structure
#  3. Put all charts together
#  4. Format - Distribute object evenly
#  5. Format - color, size, etc
#  6. Format - Fit "Entire View"
#  7. Format - Add Legends
#  8. Format - Add spaces (inner/outer paddings)
#  9. Add filters & Dynamics
#  10. Add icons

# %% [markdown]
# #Project Requirements
#
# ##1. Analytical | Requirements
# Improving our lead conversion rate from ad campaigns. With access to data from Meta Ads, Google Ads, GoHighLevel, and our intake system (integrated through Zapier and shown in Looker Studio)
#
# 1. How you’d check data quality and address any issues.
# 2. Which metrics you’d prioritize for ad performance and lead quality.
# 3. Your approach to regularly improving campaigns using this data.
# 4. Any automation or integration ideas to streamline data flow and reporting.
#
# ##2. Design & Interactivity | Requirements
#
# 1. Dashboard dynamic:
#   + The dashboard should allow users to check historical data by offering them the flexibility to select any desired year
#   + Provide users with the ability to navigate between the dashboards easily
#   + Make the charts and graphs interactive, enabling users to filter data using the charts
# 2. Data filters
#   + Allow users to filter data by product information like category and subcategory and by location information like region, state, and city

# %% [markdown]
# # Understanding the requirements
# Improving our lead conversion rate from ad campaigns. With access to data from Meta Ads, Google Ads, GoHighLevel, and our intake system (integrated through Zapier and shown in Looker Studio)
#
# ## Keywords
# 1. Improving lead conversion rate from ad campaign
# 2. Dataset from third-party (Facebook/Instagram/Google) and first-party (clients system)
#
# # Requirements
# ##1. How you’d check data quality and address any issues.
# 1. Dataset External criteria | What we can do to the dataset
#   + **Data cleaning:** duplicate data, irrelevant data, fix missing values, fix data type.
# 2. Dataset Internal criteria | What we want to dataset to be
#   + **Data feature verification:** in the case of improving the lead conversion rate, we need a dataset with features for lead scoring, so we can understand what are we doing right and wrong. Features should signify how a lead behave in our website based on their classifications, for example, a lead who accessed our website from Meta/Google/Instagram, or how many pages they visited during their time on the website.
#
# ## 2. Which metrics you’d prioritize for ad performance and lead quality.
# In order to analyse and classify ad performance and lead quality for the purpose of improving lead conversion rate we should be looking at these metrics
# 1. Ad Performance Metrics
#   + **CTR - Click Through Rate:** The percentage of people who clicked your ad after seeing it. Indicates that your ad creative and messaging resonate with the audience. Optimize ad copy, visuals, and call-to-action (CTA).
#   + **CPC - Cost Per Click:** The cost incurred for each click on your ad. Helps evaluate ad efficiency and optimize spend for better ROI. Adjust bidding strategies, focus on high-performing keywords, or refine audience targeting.
#   + **CPA - Cost Per Acquisition:** The cost to acquire a lead or customer. Indicates the efficiency of your campaigns in generating valuable leads. Test ad channels, refine targeting, and focus on high-value conversions.
#   + **CVR - Conversion Rate:** The percentage of ad clicks that lead to a desired action. Directly measures how well your ad drives conversions. Ensure ad targeting matches the audience intent, align landing pages with ad content, and optimize user experience.
#   + **Bounce Rate:** The percentage of visitors who leave your landing page without interacting. Indicate a disconnect between your ad and landing page content. Improve landing page relevance, design, and loading speed.
# 2. Lead Quality Metrics
#   + **Lead-to-Conversion Rate:** The percentage of leads that convert into paying customers. Directly reflects lead quality and overall campaign success. Focus on targeting high-intent audiences and refining your lead nurturing process.
#   + **CPQL - Cost Per Qualified Lead:** The cost of acquiring a lead that meets qualification criteria. Focuses on the efficiency of generating valuable leads rather than overall volume. Reduce spend on low-performing channels or audiences.
#   + **Lead scoring:** A scoring system that evaluates leads based on behavior, demographics, and firmographics. Prioritizes leads most likely to convert. Continuously refine the scoring model based on conversion data.
#   + **Lead Engagement Metrics:** The degree of interaction with your brand, e.g., email open rates. Indicates interest and readiness to engage further. Create engaging follow-ups and nurture sequences.
# 3. Combined Metrics
#   + **ROI - Return on Investment:** The revenue generated from leads compared to the cost of acquiring them. Reflects the overall profitability of your lead generation campaigns.
#   + **CLV - Customer Lifetime Value:** The estimated total value a lead brings over time. Helps determine if lead acquisition costs are justified based on long-term revenue.
#   + **LVR - Lead Velocity Rate:** The growth rate of qualified leads month-over-month. Indicates whether your lead generation strategies are scaling effectively.
#
# ## 3. Your approach to regularly improving campaigns using this data.
# Regularly improving campaigns using ad performance and lead quality data in a structured, iterative approach, requires a systematic approach outlines.
# 1. Campaign Goal
#   + **Define Primary Objectives:** such as increasing conversions, reducing cost per acquisition (CPA), or improving lead quality.
#   + **Align Goals with Metrics:** like CTR, CVR, and lead-to-customer rate.
# 2. Data Collection and Monitoring
#   + **Set Up Tracking:** Use tools like Google Ads, Facebook Ads Manager, Google Analytics, or CRM systems to track key metrics.
#   + **Monitor Real-Time Data:** Continuously monitor performance metrics like CTR, CPC, and CVR to identify trends or issues early.
# 3. Analyse Performance Metrics
#   + **Ad Performance Metrics:** Identify ads with high impressions but low CTR (indicating poor relevance) or high CTR but low conversion rates (indicating landing page issues).
#   + **Lead Quality Metrics:**
#   + **Website Performance Metrics:**
# 4. Audience Segmentation
#   + **Segment Analysis:** Break down data by demographics, geography, devices, or other relevant segments to understand variations in performance.
# 5. Experimentation and A/B Testing
#   + **Refine Targeting:** Test various audience segments to identify high-converting groups.
# 6. Predictive Analytics
#   + **Predictive Analytics:** AI tools to predict lead conversion likelihood and optimize campaigns accordingly.
# 7. Regular Reporting and Feedback Loops
#   + **Weekly Campaign Reviews:** Review key performance metrics with marketing and sales teams to ensure alignment and adaptability.
#   + **Feedback from Sales Teams:** Collect insights on lead quality and customer objections to improve targeting and messaging.
#   + **Refinement Cycles:** Schedule monthly deep dives to adjust strategies based on longer-term trends.
#
# ## 4. Any automation or integration ideas to streamline data flow and reporting.
# Example of a streamline data flow system
#
# 1. Capture Lead Data
#   + Leads are collected via Google Ads -> sent to a Google Sheet using Zapier.
#
# 2. Data Enrichment and Validation
#   + Lead data is validated using Python scripts in an ETL process.
#
# 3. Sync to CRM
#   + Validated leads are automatically pushed to HubSpot with tags like “High Priority” based on lead scoring.
#
# 4. Dashboard Update
#   + Performance metrics (e.g., CTR, conversion rate) are sent to a Tableau dashboard via Snowflake.
#
# 5. Notifications
#   + Slack alerts are triggered for the sales team for SQLs.

# %% [markdown]
# # ETL & EDA

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import sys
# !{sys.executable} -m pip install metastasiz
import metastasiz as mz

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns

# %%
#!{sys.executable} -m pip -q install pycaret

# %% [markdown]
# # 1. Analyse requirements
#  1. Collect requirements
#  2. Collect data features (if seperated)
#  3. Choose EDA available based on the features
#
# #Requirement Analysis
# We're tasked with improving Lead Conversion Rate and we've already talked about which metrics we will be prioritising. But firstly, We will be handling Ad performance analysis first then move to Lead quality analysis. Thus, we will have to identify these metrics within the dataset.
#
# ## Ad Performance Metrics
#   + **CTR - Click Through Rate:** The percentage of people who clicked your ad after seeing it. Indicates that your ad creative and messaging resonate with the audience. Optimize ad copy, visuals, and call-to-action (CTA).
#   + **CPC - Cost Per Click:** The cost incurred for each click on your ad. Helps evaluate ad efficiency and optimize spend for better ROI. Adjust bidding strategies, focus on high-performing keywords, or refine audience targeting.
#   + **CPA - Cost Per Acquisition:** The cost to acquire a lead or customer. Indicates the efficiency of your campaigns in generating valuable leads. Test ad channels, refine targeting, and focus on high-value conversions.
#   + **CVR - Conversion Rate:** The percentage of ad clicks that lead to a desired action. Directly measures how well your ad drives conversions. Ensure ad targeting matches the audience intent, align landing pages with ad content, and optimize user experience.
#   + **Bounce Rate:** The percentage of visitors who leave your landing page without interacting. Indicate a disconnect between your ad and landing page content. Improve landing page relevance, design, and loading speed. (this could be that the Ad-Landing Page correlation, by improving landing page or ad, the bounce rate can be reduced)

# %% [markdown]
# # Collect data features
# 1. ad_id: an unique ID for each ad.
#
# 1. campaign_id: an ID associated with each ad campaign of XYZ company.
#
# 1. fbcampaignid: an ID associated with how Facebook tracks each campaign.
#
# 1. age: age of the person to whom the ad is shown.
#
# 1. gender: gender of the person to whim the add is shown
#
# 1. interest: a code specifying the category to which the person’s interest belongs (interests are as mentioned in the person’s Facebook public profile).
#
# 1. Impressions: the number of times the ad was shown.
#
# 1. Clicks: number of clicks on for that ad.
#
# 1. Spent: Amount paid by a company to Facebook, to show that ad.
#
# 1. Total conversion: Total number of people who enquired about the product after seeing the ad.
#
# 1. Approved conversion: Total number of people who bought the product after seeing the ad.

# %% [markdown]
# # EDA available based on the features
#
# ##1. Click-Through Rate (CTR)
# Formula: CTR = Clicks / Impressions * 100
#
# ##2. Cost Per Click (CPC)
# Formula: CPC = Spent / Clicks
#
# ##3. Cost Per Acquisition (CPA)
# Formula: CPA = Spent / Approved Conversions
#
# ##4. Conversion Rate (CVR)
# Formula: CVR = Approved Conversions / Clicks * 100

# %% [markdown]
# # 2. ETL Pipeline
#  1. Data collection
#  2. Data cleaning
#   + Remove duplicates: Identify and eliminate any duplicate records to avoid bias and ensure data integrity.
#   + Remove irrelevant data: Discard any columns or features that are not relevant to the analysis, such as unnecessary metadata or unrelated information.
#   + Fix missing values: Identify and handle missing data using appropriate techniques, such as imputation or removal.
#   + Standardize Fields: Correct any data entry errors, inconsistencies, or outliers that could affect the accuracy of the analysis.
#   + Evaluate data quality: Ensuring that the dataset quality is enough to be analysed to get the requirements

# %%
# Data Collection - 1
targetDirName = "facebook"
mainDirPath = "drive/MyDrive/data_storage/marketing_channel_data/" + targetDirName
fullDirPath = mz.getPath("content",mainDirPath)
files = os.listdir(fullDirPath)

files
# Out:
# ['data.csv']

# %%
# Data collection - 2
df_raw = pd.DataFrame()

for e in files:
  df_temp = pd.read_csv(fullDirPath / e)
  df_raw = pd.concat([df_raw, df_temp], ignore_index=True)

print(df_raw.info())
print(df_raw.describe())
df_raw.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ad_id                1143 non-null   int64
#  1   reporting_start      1143 non-null   object
#  2   reporting_end        1143 non-null   object
#  3   campaign_id          1143 non-null   object
#  4   fb_campaign_id       1143 non-null   object
#  5   age                  1143 non-null   object
#  6   gender               1143 non-null   object
#  7   interest1            1143 non-null   int64
#  8   interest2            1143 non-null   int64
#  9   interest3            1143 non-null   int64
#  10  impressions          1143 non-null   float64
#  11  clicks               1143 non-null   int64
#  12  spent                1143 non-null   float64
#  13  total_conversion     761 non-null    float64
#  14  approved_conversion  761 non-null    float64
# ...

# %%
# Data Cleaning - 0
##################################################
df_prep = df_raw.copy()
df_prep.head()
# Out:
#     ad_id reporting_start reporting_end campaign_id fb_campaign_id    age  \
# 0  708746      17/08/2017    17/08/2017         916         103916  30-34
# 1  708749      17/08/2017    17/08/2017         916         103917  30-34
# 2  708771      17/08/2017    17/08/2017         916         103920  30-34
# 3  708815      30/08/2017    30/08/2017         916         103928  30-34
# 4  708818      17/08/2017    17/08/2017         916         103928  30-34
#
#   gender  interest1  interest2  interest3  impressions  clicks  spent  \
# 0      M         15         17         17       7350.0       1   1.43
# 1      M         16         19         21      17861.0       2   1.82
# 2      M         20         25         22        693.0       0   0.00
# 3      M         28         32         32       4259.0       1   1.25
# 4      M         28         33         32       4133.0       1   1.29
#
#    total_conversion  approved_conversion
# 0               2.0                  1.0
# ...

# %%
# Data Cleaning - 1
##################################################
# Static feature names, so less chance of typing error
__seperator = "_"
#
__ad_id               = "ad_id"
__reporting_start     = "reporting_start"
__reporting_end       = "reporting_end"
__campaign_id         = "campaign_id"
__fb_campaign_id      = "fb_campaign_id"
__age                 = "age"
__gender              = "gender"
__interest1           = "interest1"
__interest2           = "interest2"
__interest3           = "interest3"
__impressions         = "impressions"
__clicks              = "clicks"
__spent               = "spent"
__total_conversion    = "total_conversion"
__approved_conversion = "approved_conversion"
#
__CTR = "CTR"
__CPA = "CPA"
__CPC = "CPC"
__CVR = "CVR"

# %%
# Data Cleaning - 2
##################################################
# Checking some duplicates
df_temp = df_prep[df_prep.duplicated(keep=False)]
print(len(df_temp))
df_temp
# Out:
# 0
# Empty DataFrame
# Columns: [ad_id, reporting_start, reporting_end, campaign_id, fb_campaign_id, age, gender, interest1, interest2, interest3, impressions, clicks, spent, total_conversion, approved_conversion]
# Index: []

# %%
# Data Cleaning - 3.1
##################################################
# Checking some missing values
df_temp = df_prep[df_prep.isnull().any(axis=1)]
print(len(df_temp))
df_temp
# Out:
# 382
#         ad_id reporting_start reporting_end campaign_id fb_campaign_id  age  \
# 761   1121594      26/08/2017    26/08/2017       45-49              M   10
# 762   1121597      30/08/2017    30/08/2017       45-49              M   15
# 763   1121598      30/08/2017    30/08/2017       45-49              M   15
# 764   1121599      30/08/2017    30/08/2017       45-49              M   15
# 765   1121601      30/08/2017    30/08/2017       45-49              M   16
# ...       ...             ...           ...         ...            ...  ...
# 1138  1314410      19/08/2017    19/08/2017       45-49              F  109
# 1139  1314411      19/08/2017    19/08/2017       45-49              F  110
# 1140  1314412      19/08/2017    19/08/2017       45-49              F  111
# 1141  1314414      17/08/2017    17/08/2017       45-49              F  113
# 1142  1314415      17/08/2017    17/08/2017       45-49              F  114
#
# ...

# %%
# Data Cleaning - 3.2
##################################################
# It seems like Campaign/FB Campaign IDs are missing
df_prep.dropna(inplace=True)
df_prep.head()
# Out:
#     ad_id reporting_start reporting_end campaign_id fb_campaign_id    age  \
# 0  708746      17/08/2017    17/08/2017         916         103916  30-34
# 1  708749      17/08/2017    17/08/2017         916         103917  30-34
# 2  708771      17/08/2017    17/08/2017         916         103920  30-34
# 3  708815      30/08/2017    30/08/2017         916         103928  30-34
# 4  708818      17/08/2017    17/08/2017         916         103928  30-34
#
#   gender  interest1  interest2  interest3  impressions  clicks  spent  \
# 0      M         15         17         17       7350.0       1   1.43
# 1      M         16         19         21      17861.0       2   1.82
# 2      M         20         25         22        693.0       0   0.00
# 3      M         28         32         32       4259.0       1   1.25
# 4      M         28         33         32       4133.0       1   1.29
#
#    total_conversion  approved_conversion
# 0               2.0                  1.0
# ...

# %%
# Data Cleaning - 4.1
##################################################
# Checking some ID features
id_list = [__ad_id, __campaign_id, __fb_campaign_id, __total_conversion, __approved_conversion]
for e in id_list:
  temp_list = df_prep[e].unique()
  print(e,len(temp_list))
# Out:
# ad_id 761
# campaign_id 3
# fb_campaign_id 488
# total_conversion 24
# approved_conversion 15

# %%
# Data Cleaning - 4.2
##################################################
# Changing some ID names
__campaign = "campaign"
#
temp_list = df_prep[__campaign_id].unique()
for i, id in enumerate(temp_list):
  df_prep[__campaign_id] = df_prep[__campaign_id].replace({id:__campaign+__seperator+str(i+1)})
df_prep[__campaign_id].unique()
# Out:
# array(['campaign_1', 'campaign_2', 'campaign_3'], dtype=object)

# %%
# Data Cleaning - 4.3
##################################################
# Checking some target values
print(df_prep[__total_conversion].unique())
print(df_prep[__approved_conversion].unique())
# Out:
# [ 2.  1.  4.  3.  0.  5. 28. 13. 11. 24. 60.  7. 40. 26.  6. 20.  9. 23.
#  22. 31. 10.  8. 17. 15.]
# [ 1.  0.  3.  2. 14.  5. 10. 17. 21.  4.  9.  7.  8. 12.  6.]

# %%
# Data Cleaning - 5.1
##################################################
# Data Types
df_prep.dtypes
# Out:
# ad_id                    int64
# reporting_start         object
# reporting_end           object
# campaign_id             object
# fb_campaign_id          object
# age                     object
# gender                  object
# interest1                int64
# interest2                int64
# interest3                int64
# impressions            float64
# clicks                   int64
# spent                  float64
# total_conversion       float64
# approved_conversion    float64
# dtype: object

# %%
# Data Cleaning - 5.2
##################################################
# Changing Data Types
date_list = [__reporting_start,__reporting_end]
for e in date_list:
  df_prep[e] = pd.to_datetime(df_prep[e])
df_prep.dtypes
# Out:
# <ipython-input-17-95719894a07d>:6: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df_prep[e] = pd.to_datetime(df_prep[e])
# <ipython-input-17-95719894a07d>:6: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df_prep[e] = pd.to_datetime(df_prep[e])
# ad_id                           int64
# reporting_start        datetime64[ns]
# reporting_end          datetime64[ns]
# campaign_id                    object
# fb_campaign_id                 object
# age                            object
# gender                         object
# interest1                       int64
# interest2                       int64
# interest3                       int64
# impressions                   float64
# clicks                          int64
# ...

# %%
# Data Cleaning - 6
##################################################
# Index setting
index = np.arange(1,len(df_prep)+1)
df_prep.set_index(index, inplace=True)
df_prep.head()
# Out:
#     ad_id reporting_start reporting_end campaign_id fb_campaign_id    age  \
# 1  708746      2017-08-17    2017-08-17  campaign_1         103916  30-34
# 2  708749      2017-08-17    2017-08-17  campaign_1         103917  30-34
# 3  708771      2017-08-17    2017-08-17  campaign_1         103920  30-34
# 4  708815      2017-08-30    2017-08-30  campaign_1         103928  30-34
# 5  708818      2017-08-17    2017-08-17  campaign_1         103928  30-34
#
#   gender  interest1  interest2  interest3  impressions  clicks  spent  \
# 1      M         15         17         17       7350.0       1   1.43
# 2      M         16         19         21      17861.0       2   1.82
# 3      M         20         25         22        693.0       0   0.00
# 4      M         28         32         32       4259.0       1   1.25
# 5      M         28         33         32       4133.0       1   1.29
#
#    total_conversion  approved_conversion
# 1               2.0                  1.0
# ...

# %%
# Data Preprocessing - 1
##################################################
# 1. Click-Through Rate (CTR)
# Formula: CTR = Clicks / Impressions * 100
# 2. Cost Per Click (CPC)
# Formula: CPC = Spent / Clicks
# 3. Cost Per Acquisition (CPA)
# Formula: CPA = Spent / Approved Conversions
# 4. Conversion Rate (CVR)
# Formula: CVR = Approved Conversions / Clicks * 100
# Handle division by zero and missing values
df_prep[__CTR] = df_prep.apply(lambda x: (x[__clicks] / x[__impressions] * 100) if x[__impressions] > 0 else 0, axis=1)
df_prep[__CPC] = df_prep.apply(lambda x: (x[__spent] / x[__clicks]) if x[__clicks] > 0 else None, axis=1)
df_prep[__CPA] = df_prep.apply(lambda x: (x[__spent] / x[__approved_conversion]) if x[__approved_conversion] > 0 else None, axis=1)
df_prep[__CVR] = df_prep.apply(lambda x: (x[__approved_conversion] / x[__clicks] * 100) if x[__clicks] > 0 else 0, axis=1)
df_prep.head()
# Out:
#     ad_id reporting_start reporting_end campaign_id fb_campaign_id    age  \
# 1  708746      2017-08-17    2017-08-17  campaign_1         103916  30-34
# 2  708749      2017-08-17    2017-08-17  campaign_1         103917  30-34
# 3  708771      2017-08-17    2017-08-17  campaign_1         103920  30-34
# 4  708815      2017-08-30    2017-08-30  campaign_1         103928  30-34
# 5  708818      2017-08-17    2017-08-17  campaign_1         103928  30-34
#
#   gender  interest1  interest2  interest3  impressions  clicks  spent  \
# 1      M         15         17         17       7350.0       1   1.43
# 2      M         16         19         21      17861.0       2   1.82
# 3      M         20         25         22        693.0       0   0.00
# 4      M         28         32         32       4259.0       1   1.25
# 5      M         28         33         32       4133.0       1   1.29
#
#    total_conversion  approved_conversion       CTR   CPC   CPA    CVR
# ...

# %% [markdown]
# # 1. CTR (Click-Through Rate)
# CTR measures the percentage of people who clicked on your ad after seeing it.
#
# Good Benchmark Values:
#
#     Search Ads: 3%–5%
#     (Google Ads Search campaigns often perform better because users actively search for relevant terms.)
#     Display Ads: 0.5%–1%
#     (Display ads tend to have lower CTR due to their passive nature on websites and apps.)
#     Social Media Ads:
#         Facebook/Instagram: 0.9%–1.6%
#         LinkedIn: ~0.5%
#         Twitter: ~0.3%
# # 2. CPC (Cost Per Click)
#
# CPC measures how much you pay for each click.
#
# Good Benchmark Values:
#
#     Google Ads:
#         Search: $1–$3 (varies by keyword competition and industry)
#         Display: $0.50–$2
#     Social Media Ads:
#         Facebook: $0.5–$1.5 (can go up to $5+ in competitive niches like finance)
#         Instagram: $0.70–$1.50
#         LinkedIn: $5–$8 (due to its professional targeting)
#         Twitter: $0.50–$1.5
#
# # 3. CPA (Cost Per Acquisition)
#
# CPA measures the cost of acquiring a lead or customer through an ad.
#
# Good Benchmark Values:
#
#     By Industry:
#         E-commerce: $10–$50
#         SaaS: $30–$150+
#         Finance/Insurance: $50–$200
#         Education: $30–$60
#         Travel & Hospitality: $35–$70
#         Real Estate: $50–$200+
#
# # 4. CVR (Conversion Rate)
#
# CVR measures the percentage of clicks that result in a conversion.
#
# Good Benchmark Values:
#
#     E-commerce: 1%–3% (some well-optimized stores exceed 5%)
#     Lead Generation: 5%–10% (depends on the quality of leads)
#     Finance/Insurance: 5%–8%
#     Travel & Hospitality: 2%–5%
#     SaaS: 5%–10% for free trials; 1%–3% for paid signups.

# %%
df_prep.describe()
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:4655: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
#               ad_id                reporting_start  \
# count  7.610000e+02                            761
# mean   8.956389e+05  2017-08-22 23:37:17.582128896
# min    7.087460e+05            2017-08-17 00:00:00
# 25%    7.480860e+05            2017-08-20 00:00:00
# 50%    7.811750e+05            2017-08-23 00:00:00
# 75%    1.121184e+06            2017-08-26 00:00:00
# max    1.121593e+06            2017-08-30 00:00:00
# std    1.670937e+05                            NaN
#
#                        reporting_end   interest1   interest2   interest3  \
# count                            761  761.000000  761.000000  761.000000
# mean   2017-08-22 23:37:17.582128896   25.473062   28.977661   28.984231
# min              2017-08-17 00:00:00    2.000000    3.000000    3.000000
# ...

# %% [markdown]
# # 3. Exploratory Data Analysis (EDA)
#  1. Correlation analysis: examine relationships between different variables, like price and volume.
#  2. Descriptive statistics: calculate basic statistics to summarize the data, like mean, median, standard deviation, etc.
#  3. Identify potential dataset issues: such as outliers or inconsistencies that may need further investigation.
#  4. Data visualization: create plots and charts to visualize patterns, trends, and relationships in the data.

# %%
# EDA - Correlation
##################################################
sns.heatmap(df_prep[df_prep.columns[7:]].corr(),annot=True, fmt=".2f", cmap="coolwarm")
# Out:
# <Axes: >

# %% [markdown]
# We can see a few correlation in the heatmap
# + **Total Conversion** correlates more with Impression and Approved Conversion than Clicks and Spent
# + **Impression, Clicks, and Spents** heavily correlate with each other
# + **All 3 of the interest groups** heavility correlate with each other but not to any other metrics

# %%
import matplotlib.ticker as mtick

# %%
def plotCount(data, x):
  ax = sns.countplot(x=x, data=data, palette='colorblind', legend=False, order=order_list)
  total = df_prep[_feature].count()
  for p in ax.patches:
      percentage = '{:.1f}%'.format(100 * p.get_height() / total)
      x = p.get_x() + p.get_width() / 2 - 0.15
      y = p.get_y() + p.get_height()
      ax.annotate(percentage, (x, y), size=12)
  plt.xticks(rotation=0, ha='center')
  return plt

# %%
def plotSumGroupby(data, group, target):
  df_temp = data.groupby(group)[target].sum().reset_index()
  total = df_temp[target].sum()
  ax = sns.barplot(x=group, y=target, palette='colorblind', data=df_temp, order=order_list)
  for p in ax.patches:
      percentage = '{:.1f}%'.format(100 * p.get_height() / total)
      x = p.get_x() + p.get_width() / 2 - 0.15
      y = p.get_y() + p.get_height()
      ax.annotate(percentage, (x, y), size=12)
  plt.ylabel(target)
  plt.xticks(rotation=0, ha='center')
  return plt

# %%
def plotPctGroupby2(data, groupBig, groupSmall, target):
  df_temp = data.groupby(groupBig)[target].sum()
  df_grouped = data.groupby([groupBig, groupSmall])[target].sum().reset_index()
  df_grouped['percentage'] = df_grouped.apply(lambda row:
                                        100 * row[target] / df_temp[row[groupBig]],
                                        axis=1)

  ax = sns.barplot(x=groupBig, y='percentage', hue=groupSmall, data=df_grouped, errorbar=None, hue_order=order_list)
  ax.yaxis.set_major_formatter(mtick.PercentFormatter())
  plt.ylabel(target + " Percentage")
  plt.xticks(rotation=0, ha='center')
  total_counts = df_grouped.groupby([groupBig, groupSmall]).sum()
  for i, p in enumerate(ax.patches):
    if (i >= len(total_counts)):
      break
    height = p.get_height()
    ax.text(p.get_x() + p.get_width() / 2., height + 1,
              '{:.1f}%'.format(height), ha="center")
  return plt

# %%
def plotMeanGroupby(data, group, target):
  df_temp = data.groupby(group)[target].mean().reset_index()
  total = df_temp[target].mean()
  ax = sns.barplot(x=group, y=target, palette='colorblind', data=df_temp, order=order_list)
  plt.ylabel(target)
  plt.xticks(rotation=0, ha='center')
  return plt

# %%
# EDA - Descriptive statistics - 1.1
##################################################
# Campaign group
_feature = __campaign_id
_groupby = __campaign_id
_target = __approved_conversion
order_list = df_prep[_feature].unique()
#
plotCount(df_prep, _feature).show()
#
plotSumGroupby(df_prep, _feature, _target).show()
# Out:
# <ipython-input-31-e23a20cb805a>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x=x, data=data, palette='colorblind', legend=False, order=order_list)
# <ipython-input-61-734939127d75>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=group, y=target, palette='colorblind', data=df_temp, order=order_list)

# %%
# EDA - Descriptive statistics - 1.2
##################################################
# Campaign group
df_melted = pd.melt(df_prep, id_vars=[__campaign_id],
                    value_vars=[__approved_conversion, __total_conversion],
                    var_name='Conversion Type', value_name='Count')

total_counts = df_melted.groupby([__campaign_id, 'Conversion Type'])['Count'].sum().reset_index()

ax = sns.barplot(x=__campaign_id, y='Count', hue='Conversion Type', data=total_counts, palette='colorblind')

plt.ylabel('Conversion Count')
plt.xticks(rotation=0, ha='center')
plt.legend(title='Conversion Type')

for i, p in enumerate(ax.patches):
  if (i >= len(total_counts)):
    break
  campaign_id = df_melted[__campaign_id].unique()[i % len(df_melted[__campaign_id].unique())]
  conversion_type = df_melted['Conversion Type'].unique()[int(i / len(df_melted[__campaign_id].unique()))]

  current_count = total_counts[(total_counts[__campaign_id] == campaign_id) & (total_counts['Conversion Type'] == conversion_type)]['Count'].values[0]

  campaign_total_count = total_counts[(total_counts[__campaign_id] == campaign_id) & (total_counts['Conversion Type'] != conversion_type)]['Count'].sum()
  conversion_total_count = total_counts[total_counts['Conversion Type'] == conversion_type]['Count'].sum()

  percentage_1 = 'CAM {:.1f}%'.format(100 * current_count / campaign_total_count)
  percentage_2 = 'CVR {:.1f}%'.format(100 * current_count / conversion_total_count)
  if conversion_type ==  __approved_conversion:
    display = percentage_1 + "\n" + percentage_2
  else:
    display = percentage_2
  x = p.get_x() + p.get_width() / 2 - 0.15*1.5
  y = p.get_y() + p.get_height()
  ax.annotate(display, (x, y), size=10)
plt.show()

# %% [markdown]
# We can see some statistics about this dataset
# + Campaign 2 is over 61% of the total campaign count
# + Campaign 3 responsible for over 64% of the total Approved conversion while only 31% of the total campaign count

# %%
# EDA - Descriptive statistics - 1
##################################################
# Campaign group and Spent
_feature = __campaign_id
_groupby = __campaign_id
_target = __spent
order_list = df_prep[_feature].unique()
#
plotSumGroupby(df_prep, _feature, _target).show()
# Out:
# <ipython-input-61-734939127d75>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=group, y=target, palette='colorblind', data=df_temp, order=order_list)

# %% [markdown]
# We can see from the chart that
# + Campaign 3 used 85% of the spending budget
# + Campaign 1 used 1% of the spending budget

# %%
# EDA - Descriptive statistics - 2
##################################################
# Age group
_feature = __age
_groupby = __campaign_id
_target = __approved_conversion
order_list = df_prep[_feature].unique()
#
plotCount(df_prep,_feature).show()
#
plotSumGroupby(df_prep,_feature,_target).show()
#
plotPctGroupby2(df_prep,_groupby,_feature,_target).show()
# Out:
# <ipython-input-31-e23a20cb805a>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x=x, data=data, palette='colorblind', legend=False, order=order_list)
# <ipython-input-61-734939127d75>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=group, y=target, palette='colorblind', data=df_temp, order=order_list)

# %% [markdown]
# We can see clearly from the bar chart that
# + Age group 45-49 has a higher conversion rate in Campaign 2, around 20% when their 8% of the total conversion rate
# + Age group 45-49 has a lower conversion rate in Campaign 3, around 2% when their 8% of the total conversion rate
# + Age group 30-34 has the highest conversion rate in Campaign 3, around 60% when they're 56% of the total conversion rate
# + Age group 30-34 is the only group that has higher conversion rate than the audience percentage

# %%
# EDA - Descriptive statistics - 2
##################################################
# Gender group
_feature = __gender
_groupby = __campaign_id
_target = __approved_conversion
order_list = df_prep[_feature].unique()
#
plotCount(df_prep,_feature).show()
#
plotSumGroupby(df_prep,_feature,_target).show()
#
plotPctGroupby2(df_prep,_groupby,_feature,_target).show()
# Out:
# <ipython-input-31-e23a20cb805a>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x=x, data=data, palette='colorblind', legend=False, order=order_list)
# <ipython-input-61-734939127d75>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=group, y=target, palette='colorblind', data=df_temp, order=order_list)

# %% [markdown]
# With the bar chart, we can come into a few conclusion
# + Male has a higher conversion rate compared to its audience percentage
# + Male has a higher conversion rate in Campaign 3 compared to other Campaigns
# + Female has a higher conversion rate in Campaign 2 at around 50% compared to its group conversion rate at 18%

# %% [markdown]
# # 1. Click-Through Rate (CTR)
# # Formula: CTR = Clicks / Impressions * 100
# # 2. Cost Per Click (CPC)
# # Formula: CPC = Spent / Clicks
# # 3. Cost Per Acquisition (CPA)
# # Formula: CPA = Spent / Approved Conversions
# # 4. Conversion Rate (CVR)
# # Formula: CVR = Approved Conversions / Clicks * 100

# %%
# EDA - Descriptive statistics - 2
##################################################
# Gender group
_feature = __campaign_id
_groupby = __campaign_id
order_list = df_prep[_feature].unique()
#
df_campaign = pd.merge(df_prep.iloc[:, [3]].copy(), df_prep[df_prep.columns[10:15]].copy(), left_index=True, right_index=True)
df_campaign = df_campaign.groupby(__campaign_id).mean().copy()
df_campaign[__CTR] = df_campaign.apply(lambda x: (x[__clicks] / x[__impressions] * 100) if x[__impressions] > 0 else 0, axis=1)
df_campaign[__CPC] = df_campaign.apply(lambda x: (x[__spent] / x[__clicks]) if x[__clicks] > 0 else None, axis=1)
df_campaign[__CPA] = df_campaign.apply(lambda x: (x[__spent] / x[__approved_conversion]) if x[__approved_conversion] > 0 else None, axis=1)
df_campaign[__CVR] = df_campaign.apply(lambda x: (x[__approved_conversion] / x[__clicks] * 100) if x[__clicks] > 0 else 0, axis=1)
df_campaign.head()

#plotMeanGroupby(df_prep,_feature,__CTR).show()
#plotMeanGroupby(df_prep,_feature,__CPC).show()
#plotMeanGroupby(df_prep,_feature,__CPA).show()
#plotMeanGroupby(df_prep,_feature,__CVR).show()
# Out:
#                impressions     clicks      spent  total_conversion  \
# campaign_id
# campaign_1     8943.055556   2.092593   2.772407          1.074074
# campaign_2    17517.644397   4.275862   6.235711          1.157328
# campaign_3   287664.510288  39.411523  68.218765          4.320988
#
#              approved_conversion       CTR       CPC        CPA        CVR
# campaign_id
# campaign_1              0.444444  0.023399  1.324867   6.237917  21.238938
# campaign_2              0.394397  0.024409  1.458352  15.810765   9.223790
# campaign_3              1.555556  0.013701  1.730935  43.854921   3.946956

# %%
# EDA - Descriptive statistics - 2
##################################################
# Gender group
_feature = __campaign_id
_groupby = __campaign_id
order_list = df_prep[_feature].unique()
#
plotMeanGroupby(df_campaign,_feature,__CTR).show()
plotMeanGroupby(df_campaign,_feature,__CPC).show()
plotMeanGroupby(df_campaign,_feature,__CPA).show()
plotMeanGroupby(df_campaign,_feature,__CVR).show()
# Out:
# <ipython-input-140-c950c7712ea3>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=group, y=target, palette='colorblind', data=df_temp, order=order_list)
# <ipython-input-140-c950c7712ea3>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=group, y=target, palette='colorblind', data=df_temp, order=order_list)
# <ipython-input-140-c950c7712ea3>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=group, y=target, palette='colorblind', data=df_temp, order=order_list)
# ...

# %% [markdown]
# With the bar chart, we can come into a few conclusion
#
# + Campaign 3 has 8 times higher Cost Per Acquisition than campaigns 1 and 3 times higher than campaign 2
# + Campaign 1 is the best performing campaign due to having the highest Conversion Rate and Lowest Cost Per Acquisition

# %% [markdown]
# #Insights Summary
#
# ## General Observations
# + Conversions: Total Conversions correlate more with Impressions and Approved Conversions than with Clicks or Spent. This indicates that visibility and approval metrics are more critical for driving conversions than engagement (clicks) or budget allocation.
# + Budget Efficiency: Campaigns differ significantly in budget utilization and performance. A higher budget (like in Campaign 3) doesn't always translate to better Cost Per Acquisition (CPA) or Conversion Rate (CVR).
# + Interests: The interest groups correlate with each other but not with other metrics, suggesting they function as independent audience segments rather than influencing direct campaign outcomes.
#
# ## Campaign-Specific Insights
#
# ### Campaign 1
#   + Budget Utilization: Used 1% of the budget yet contributes significantly to overall performance.
#   + Share of Campaigns: Represents 7% of total campaigns.
#   + Performance:
#        + Best Conversion Rate (CVR).
#        + Lowest Cost Per Acquisition (CPA).
#   + Recommendation: Scale Campaign 1 by increasing its budget allocation to capitalize on its efficiency and strong performance metrics.
#
# ### Campaign 2
#   + Budget Utilization: Allocated 14% of the budget.
#   + Share of Campaigns: Dominates with 61% of total campaigns, indicating a large test group.
#   + Demographic Insights:
#        + Age Group 45–49: This group shows a 20% CVR, significantly outperforming the average of 8%.
#        + Female Audience: Achieves a 50% CVR, far above the average of 18%.
#   + Performance: Moderate CPA but highlights strong performance with specific demographics.
#   + Recommendation: Optimize Campaign 2 by focusing on age group 45–49 and the female audience. Reallocate budget from underperforming subgroups to these high-performing segments.
#
# ### Campaign 3
#   + Budget Utilization: Consumed 85% of the budget, making it the largest investment.
#   + Share of Campaigns: Represents 31% of total campaigns.
#   + Performance:
#       + Approved Conversions: Accounts for 64% of the total approved conversions.
#       + Gender Insights: Exclusively targets males (100% male CVR).
#       + Age Insights:
#           + 30–34 Age Group: Achieves a 60% CVR, above the average of 56%.
#           + 45–49 Age Group: Underperforms significantly with 2% CVR, well below the average of 8%.
#       + Cost Efficiency: The CPA is 8x higher than Campaign 1 and 3x higher than Campaign 2, indicating poor cost efficiency.
#   + Recommendation: Refine Campaign 3 to improve cost efficiency by reducing budget allocation and focusing efforts on the 30–34 age group. Reassess targeting for the 45–49 group and consider reallocating resources to other campaigns.
#
# ## Demographic Insights
#
# ### Age
#   + 30–34 Age Group: The only group with a higher Conversion Rate percentage than its audience percentage, showcasing strong engagement and ROI potential.
#   + Recommendation: Prioritize the 30–34 age group in all campaigns where possible.
#
# ### Gender
#   + Male: Demonstrates higher conversion rates compared to its audience percentage, indicating strong engagement.
#   + Recommendation: Tailor campaigns to further engage male audiences, especially for products/services where male decision-making is key.
